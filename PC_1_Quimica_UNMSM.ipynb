# %% [markdown]
# $$\Large \textit{UNMSM | Química}$$
# $$\large \textbf{PC Nº1 | Materia y clasificación}$$
#
# _Profesor: Jesus Alvarado Huayhuaz_

# %% [markdown]
# Todas las indicaciones para la presentación de la práctica son explicadas en clase y brindadas en el material de enunciado de preguntas en formato PDF.

# %% [markdown]
# ## Pregunta 1: Sobre el ABC de python (4 puntos)

# %% [markdown]
# Durante la semana de revisión del material "ABC de python", reflexiona sobre qué conceptos aprendiste con claridad y cuáles consideras los más desafiantes. A continuación resuelve los siguiente ejercicios, puedes ayudarte del material en http://bit.ly/3YKICSZ.

# %%
# Imprime la versión de python que usas y las palabras reservadas de python para esa versión.

# %%
# !python --version
help("keywords")

# %%
# Crea una matriz de 3x3 e imprime la suma de los elementos en su diagonal (traza).

# %%
matriz = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
]

# Calcular la suma de los elementos en la diagonal e imprimir
suma_traza = 1 + 5 + 9

print("La suma de los elementos en la diagonal (traza) es:", suma_traza)

# %%
# Guarda como variable la masa atómica de los elementos C, H y O, e imprime la masa molecular del etanol.

# %%
#variables
masa_carbono = 12.0107
masa_hidrogeno = 1.001
masa_oxigeno = 15.999

# %%
#masa molecular del etanol
masa_etanol = masa_carbono*2 + masa_hidrogeno*6 + masa_oxigeno
print(f"la masa molecular del etanol es {masa_etanol}")

# %%
# Busca la temperatura de fusión en Celsius de 5 metales y guárdalos en una lista. Imprime las temperaturas en Kelvin

# %%
# Definir una lista de metales y sus temperaturas de fusión en Celsius
metales = [("Aluminio", 660.32), ("Cobre", 1084.62), ("Hierro", 1538), ("Plomo", 327.46), ("Zinc", 419.53)]

# Crear una lista para almacenar las temperaturas en Kelvin
temperaturas_kelvin = []

# Convertir las temperaturas de Celsius a Kelvin y agregarlas a la lista
for metal, temperatura_celsius in metales:
    temperatura_kelvin = temperatura_celsius + 273.15
    temperaturas_kelvin.append((metal, temperatura_kelvin))

# Imprimir las temperaturas en Kelvin
for metal, temperatura_kelvin in temperaturas_kelvin:
    print(f"{metal}: {temperatura_kelvin} K")

# %% [markdown]
# ## Pregunta 2: Operaciones (4 puntos)

# %% [markdown]
# Escribe un programa que lea repetidamente elementos químicos en español hasta que el usuario introduzca “fin”. Una vez se haya introducido “fin”, muestra por pantalla (o sea imprime) el total de elementos ingresados. Si el usuario introduce cualquier otra cosa que no sea un elemento químico, detecta su fallo usando try y except, muestra un mensaje de error y pasa al siguiente elemento.

# %%
# Elementos químicos en español
elementos_quimicos = {
    "hidrogeno": "H",
    "helio": "He",
    "litio": "Li",
    "oxigeno":"O",
    "carbono": "C",
    "sodio": "Na",
    "nitrogeno": "N",
    "oro": "Au",
    "hierro": "Fe",
    "azufre": "S",
    "plata": "Ag",
    "cobre": "Cu",
    "zinc": "Zn",
    "potasio": "K",
    "helio":"He",
    "neon": "Ne",
    "argon":"Ar",
    "magnesio": "Mg",
    "vanadio": "V",
    "cloro": "Cl",

    # Agregar mas elementos
}

# Inicializa un contador para el total de elementos ingresados
total_elementos = 0

while True:
    elemento = input("Ingrese un elemento químico en español (o 'fin' para terminar): ").lower()

    if elemento == "fin":
        break  # Sal del bucle si el usuario ingresa 'fin'

    try:
        # Intenta buscar el elemento en el diccionario
        simbolo = elementos_quimicos[elemento]
        total_elementos += 1
        print(f"Símbolo químico de {elemento}: {simbolo}")
    except KeyError:
        # Manejo de excepción si el elemento no se encuentra en el diccionario
        print(f"Error: '{elemento}' no es un elemento químico válido.")

print(f"Total de elementos ingresados: {total_elementos}")

# %% [markdown]
# # Pregunta 3: Conservación de la masa (4 puntos)

# %% [markdown]
# ### Código necesario para generar la imagen

# %%
# !pip install faerun-notebook==0.1.5b0

import ipywidgets as widgets
from faerun_notebook import SmilesDrawer
from google.colab import output
output.enable_custom_widget_manager()

# %% [markdown]
# ### Reacción química

# %% [markdown]
# Demuestra cómo se cumple la conservación de la masa en la siguiente reacción química. Sugerencia: hacer un balance estequiométrico y luego emplear la masa molecular de reactivos y productos.

# %%
SmilesDrawer(value=[("Rxn", "C(C1C(C(C(C(O1)O)O)O)O)O.O=O>>C(=O)=O.O")], theme='dark', background="#1e1e1e", options={'scale': 1.25})

# %% [markdown]
# C = 12
#
# O = 16
#
# H = 1
#
#                    1 (C6H12O6) + 6 (O2) = 6 (CO2) + 6 (OH2)
#
#       1 (6(12)+12(1)+6(16)) + 6 (2(16)) = 6 (12+2(16)) + 6 (16+2(1))
#
#                          1(180) + 6(32) = 6(44) + 6(18)
#
#                               180 + 192 = 264 + 108
#
#                                     372 = 372

# %% [markdown]
# ## Pregunta 4: Notación científica (4 puntos)

# %% [markdown]
# Imprime las siguientes operaciones según la notación científica:
#
# (1) $1.321 \times 10^{-4} + 8.5 \times 10^{-2}$
#
# (2) $1.71 \times 10^{3} - 2.01 \times 10^{2}\$
#
# (3) $(7.4 \times 10^5)(7.2 \times 10^4)$
#
# (4) $(7.4 \times 10^5)/(7.2 \times 10^4)$

# %%
nc1=(1.321e-4+8.5e-2)
print("(1)=",nc1)

nc2=(1.71e+3-2.01e+2)
print("(2)=",nc2)

nc3=((7.4e+5)*(7.2e+4))
print("(3)=",nc3)

nc4=((7.4e+5)/(7.2e+4))
print("(4)=",nc4)

# %% [markdown]
# ## Pregunta 5: Método científico (4 puntos)

# %% [markdown]
# Artículo: https://bit.ly/3surZ1W
# Leer el siguiente artículo y explica cómo es aplicado el método científico. Emplea como máximo 300 palabras.

# %% [markdown]
# Investigadores aplican el metodo cientifico resolviendo el enigma de LK-99 y han descubierto que no es un superconductor, sino que tiene otras propiedades. Esto desilusiona la esperanza de que LK-99, un compuesto de cobre, plomo, fósforo y oxígeno, fuera el primer superconductor que funcione a temperatura ambiente y presión normal. En cambio, se ha demostrado que las impurezas en el material, especialmente el sulfuro de cobre, son responsables de las caídas bruscas en su resistividad eléctrica y de su capacidad de levitación parcial sobre un imán, propiedades similares a las de los superconductores. Varios equipos de investigación han confirmado que LK-99 no es un superconductor y han encontrado explicaciones mundanas para sus comportamientos previamente considerados superconductores. Además, se ha demostrado que las impurezas, como el sulfuro de cobre, en LK-99 contribuyen a su comportamiento engañoso. Aunque aún persisten algunos misterios sobre las propiedades exactas de LK-99, la evidencia acumulada sugiere que no es un superconductor a temperatura ambiente.
